# %%
import matplotlib.pyplot as plt
import matplotlib
# %matplotlib inline 
# %config InlineBackend.figure_format = 'retina'   # enable if you have a retina display
matplotlib.rc('font', size = 16)                 # Use big fonts...
plt.rcParams['figure.figsize'] = (10, 8)         # ... and big plots

import numpy as np
import pandas as pd
from matplotlib.colors import LogNorm

# %%
x = pd.read_csv('/Users/josephhowlett/Downloads/fig_5-run_03_04-0-points/result-efficiency-run_03_04-0-points-data.csv')

# %%
plt.scatter(x.time, x.xL_data)
